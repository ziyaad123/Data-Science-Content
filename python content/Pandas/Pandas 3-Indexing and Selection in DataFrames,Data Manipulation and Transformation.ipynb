# %%
import pandas as pd

# %%
df=pd.read_csv("D:\STUDY\Coding\Jupyter Notebook\DATA SCIENCE\EDA\LOAN DATA analysis\DATA SET\Loan 1.csv")

# %%
df.head()#head tag used to get first 5 rows of the data set by deafult
#and can be changed by putting values in brackets (df.head(10)-returns 10 columns) for fecthing more rows
# Out:
#   Customer ID              Name Gender  Age  Income (USD) Income Stability  \
# 0     C-26247  Tandra Olszewski      F   47       3472.69              Low
# 1     C-35067     Jeannette Cha      F   57       1184.84              Low
# 2     C-34590      Keva Godfrey      F   52       1266.27              Low
# 3     C-16668      Elva Sackett      M   65       1369.72             High
# 4     C-12196    Sade Constable      F   60       1939.23             High
#
#              Profession Type of Employment    Location  \
# 0  Commercial associate           Managers  Semi-Urban
# 1               Working        Sales staff       Rural
# 2               Working                NaN  Semi-Urban
# 3             Pensioner                NaN       Rural
# 4             Pensioner                NaN       Urban
#
#    Loan Amount Request (USD)  ...  Dependents Credit Score No. of Defaults  \
# 0                  137088.98  ...         2.0       799.14               0
# ...

# %% [markdown]
# #

# %% [markdown]
# # INDEXING AND SLICING

# %% [markdown]
# #

# %% [markdown]
# ## LOC
# ### "Loc is used to filter rows and select columns by lable[Rows-"Row's Index", column-"Column's Name"]"
# lets take an example-

# %%
df.loc[0,"Name"]#returns value at index 0 of column name Name
#here slicing is being done for 0 index name
# Out:
# 'Tandra Olszewski'

# %%
#lets see now multiple data fetch using loc
df.loc[[0,1,2],:]#at row part we gave index 0,1,2 and at column we gave : which means it will return all data for first 3 rows
           #OR
df.loc[0:3,:]
# Out:
#   Customer ID              Name Gender  Age  Income (USD) Income Stability  \
# 0     C-26247  Tandra Olszewski      F   47       3472.69              Low
# 1     C-35067     Jeannette Cha      F   57       1184.84              Low
# 2     C-34590      Keva Godfrey      F   52       1266.27              Low
# 3     C-16668      Elva Sackett      M   65       1369.72             High
#
#              Profession Type of Employment    Location  \
# 0  Commercial associate           Managers  Semi-Urban
# 1               Working        Sales staff       Rural
# 2               Working                NaN  Semi-Urban
# 3             Pensioner                NaN       Rural
#
#    Loan Amount Request (USD)  ...  Dependents Credit Score No. of Defaults  \
# 0                  137088.98  ...         2.0       799.14               0
# 1                  104771.59  ...         2.0       833.31               0
# 2                  176684.91  ...         3.0       627.44               0
# ...

# %% [markdown]
# ###### A Big Difference Between Loc and Iloc Is That If a Range Is Given Like 0:3 It Includes the 3, Whereas Iloc Doesn't.

# %%
df.loc[df.Age==21,"Name"]#return Name of all people at the age of 21....
# FACT- Using loc is much more efficient then compare to normal indexing
# Out:
# 60         Deborah Alanis
# 192      Earlie Seabrooks
# 291        Dorotha Vaughn
# 377       Federico Bouska
# 408         Claris Wynter
#                ...
# 19781         Sid Richart
# 19873         Lucio Kosak
# 19912         Nana Girard
# 19998      Mariana Pulver
# 19999     Mechelle Boddie
# Name: Name, Length: 314, dtype: object

# %% [markdown]
# ## ILOC
# #### "iloc is used to filter rows and columns based on integer position"
# ##### df.iloc[index_of_rows,index_of_column]

# %%
df.iloc[0:4,[0,1,3]]# here the row index are list containing(0,1,2,4) and index of column 0,1,3 i.e, [Customer ID,NAME,Age]
# Out:
#   Customer ID              Name  Age
# 0     C-26247  Tandra Olszewski   47
# 1     C-35067     Jeannette Cha   57
# 2     C-34590      Keva Godfrey   52
# 3     C-16668      Elva Sackett   65

# %% [markdown]
# ##### A Big Difference Between Loc and Iloc Is That If a Range Is Given Like 0:3 It Includes the 3, Whereas Iloc Doesn't.

# %%
df.columns
# Out:
# Index(['Customer ID', 'Name', 'Gender', 'Age', 'Income (USD)',
#        'Income Stability', 'Profession', 'Type of Employment', 'Location',
#        'Loan Amount Request (USD)', 'Current Loan Expenses (USD)',
#        'Expense Type 1', 'Expense Type 2', 'Dependents', 'Credit Score',
#        'No. of Defaults', 'Has Active Credit Card', 'Property ID',
#        'Property Age', 'Property Type', 'Property Location', 'Co-Applicant',
#        'Property Price'],
#       dtype='object')

# %% [markdown]
# ## Boolean Indexing

# %% [markdown]
# we want to select all rows in the DataFrame where the Age is greater than or equal to 30. We can create a boolean mask using a comparison operation

# %%
mask = df['Age'] >= 65

# %% [markdown]
# This creates a Series of booleans with the same length as the DataFrame, where each value is True if the corresponding value in the Age column is greater than or equal to 30, and False otherwise.

# %%
# We can then use this mask to filter the DataFrame using the loc attribute:
df.loc[mask]
# Out:
#       Customer ID                 Name Gender  Age  Income (USD)  \
# 3         C-16668         Elva Sackett      M   65       1369.72
# 7          C-2206      Karrie Dickison      M   65       1403.63
# 55        C-27558  Margarito Ratchford      F   65       1383.98
# 76         C-6321      Jong Fredenburg      M   65        673.71
# 112       C-38418     Tatyana Stephens      F   65       2802.82
# ...           ...                  ...    ...  ...           ...
# 19903     C-36910     Kristeen Sarabia      F   65       2803.88
# 19913      C-8634          John Donato      F   65       1158.19
# 19974      C-7582       Desire Collado      M   65       2221.89
# 19977     C-47754      Stella Mccleery      F   65        911.45
# 19990     C-11765        Josette Pharr      M   65       2648.04
#
#       Income Stability Profession Type of Employment    Location  \
# 3                 High  Pensioner                NaN       Rural
# ...

# %% [markdown]
# ### We can also use boolean indexing to select specific columns based on a condition.
# ### For example, to select all columns where the label contains the word "Type",
# ### we can create a boolean mask using the str.contains method:

# %%
mask = df.columns.str.contains('Type')
'''This creates a boolean mask with the same length as the number of columns, 
where each value is True if the corresponding column label contains the word "Type", and False otherwise.'''
# Out:
# 'This creates a boolean mask with the same length as the number of columns, \nwhere each value is True if the corresponding column label contains the word "Type", and False otherwise.'

# %%
df.loc[:,mask]# we can see column name which has type keyowrd in it
# Out:
#       Type of Employment Expense Type 1 Expense Type 2  Property Type
# 0               Managers              N              N              2
# 1            Sales staff              Y              Y              1
# 2                    NaN              N              Y              1
# 3                    NaN              N              Y              1
# 4                    NaN              N              N              4
# ...                  ...            ...            ...            ...
# 19995                NaN              Y              Y              4
# 19996         Core staff              Y              Y              4
# 19997         Core staff              Y              N              2
# 19998                NaN              N              Y              1
# 19999           Laborers              Y              Y              4
#
# [20000 rows x 4 columns]

# %% [markdown]
# ### Boolean indexing is a powerful and flexible way to filter and select data in a DataFrame based on complex conditions.

# %% [markdown]
# LETS TAKE EXAMPLE IN THE DATA SET:

# %% [markdown]
# #### Example 1: Let's say we want to select all rows in the DataFrame where the Age is greater than or equal to 30 and the Income (USD) is greater than 5,000. We can create a boolean mask using comparison operations:

# %%
mask=(df['Age'] >= 30) & (df['Income (USD)'] > 5000)
df.loc[mask]
# Out:
#       Customer ID               Name Gender  Age  Income (USD)  \
# 15         C-1281      Trinidad Quam      F   60       5591.39
# 24        C-24580   Loriann Gagliano      M   49       5787.21
# 81        C-24776     Herbert Rippel      F   36       8666.14
# 130        C-8598      Merideth Loos      F   58       5963.91
# 135        C-5924    Luvenia Wetzler      F   51       6258.19
# ...           ...                ...    ...  ...           ...
# 19786     C-27812  Antonietta Simons      F   39       8270.93
# 19790     C-11433      America Moats      F   63       8414.09
# 19815     C-25533       Krystin Duda      M   32       6963.10
# 19840     C-24886   Darlena Warfield      F   62       5419.24
# 19991      C-5442      Genaro Aponte      F   57       5185.72
#
#       Income Stability            Profession Type of Employment    Location  \
# 15                 NaN             Pensioner                NaN       Urban
# ...

# %% [markdown]
# The Mask creates a Series of booleans with the same length as the DataFrame, where each value is True if the corresponding row satisfies both conditions, and False otherwise.
#
# This returns a new DataFrame containing only the rows where the mask is True.

# %% [markdown]
# #### EXAMPLE 2: Let's say we want to find out how many people have a credit score of 700 or above. We can do this using boolean indexing like this:

# %%
mask = df['Credit Score'] >= 700
num_people = df[mask]['Name'].count()

# %% [markdown]
# #

# %% [markdown]
# # Data Manipulation and Transformation

# %% [markdown]
# ### Reshaping:
#
# 1. **Pivoting**:
#    - `pivot()`: Rotates data from rows into columns based on a key column.
#
# 2. **Melting**:
#    - `melt()`: Converts data from wide format to long format.
#
# 3. **Stacking/Unstacking**:
#    - `stack()`: Collapses DataFrame columns into a single column.
#    - `unstack()`: Reverse operation of stacking.
#
# 4. **Reshaping with pivot_table**:
#    - `pivot_table()`: Similar to `pivot`, but can handle duplicate entries by applying an aggregation function.
#
# ### Transforming:
#
# 1. **Grouping and Aggregation**:
#    - `groupby()`: Groups data based on one or more keys.
#    - `agg()`: Applies aggregate functions like sum, mean, etc.
#
# 2. **Resampling and Time-series Transformation**:
#    - `resample()`: Resamples data over different time frequencies.
#
# 3. **Applying Functions**:
#    - `apply()`: Applies custom functions to rows, columns, or entire DataFrame.
#
# 4. **Dropping Duplicates**:
#    - `drop_duplicates()`: Removes duplicate rows based on a subset of columns or all columns.
#
# 5. **Renaming Columns**:
#    - `rename()`: Renames columns to make them more readable or consistent.

# %% [markdown]
# # Reshaping:
#
# ## 1.Pivoting:
# Suppose you want to reshape the data to have a separate column for each Type of Employment, with values being the Loan Amount Request (USD).

# %%
df.pivot(index=['Customer ID', 'Name'], columns='Type of Employment', values='Loan Amount Request (USD)')
# Out:
# Type of Employment                  NaN  Accountants  Cleaning staff  \
# Customer ID Name
# C-10        Verlene Claybrook       NaN          NaN             NaN
# C-1000      Kathey Tome             NaN          NaN             NaN
# C-10001     Margurite Oakman        NaN          NaN             NaN
# C-10003     Rolf Hyppolite          NaN     88280.17             NaN
# C-10005     Benton Kanagy           NaN          NaN             NaN
# ...                                 ...          ...             ...
# C-9982      Lesley Bober            NaN          NaN             NaN
# C-9988      Paulene Bulfer     15825.45          NaN             NaN
# C-9993      Leeanna Leech           NaN          NaN             NaN
# C-9995      Lenita Seigler          NaN          NaN             NaN
# C-9998      Madalyn Sorrels         NaN          NaN             NaN
#
# Type of Employment             Cooking staff  Core staff  Drivers  HR staff  \
# Customer ID Name
# ...

# %% [markdown]
# ## 2.Melting:
# If you want to convert the wide format of the dataset to a long format, where each row represents a single variable and its value, you can use melt().

# %%
pd.melt(df, id_vars=['Customer ID', 'Name'], var_name='Variable', value_name='Value')
# Out:
#        Customer ID              Name        Variable      Value
# 0          C-26247  Tandra Olszewski          Gender          F
# 1          C-35067     Jeannette Cha          Gender          F
# 2          C-34590      Keva Godfrey          Gender          F
# 3          C-16668      Elva Sackett          Gender          M
# 4          C-12196    Sade Constable          Gender          F
# ...            ...               ...             ...        ...
# 419995      C-9076    Tobias Davilla  Property Price     212778
# 419996     C-17587    Evelina Hodges  Property Price   90816.95
# 419997     C-46479   Karlyn Mckinzie  Property Price   21566.27
# 419998      C-3099    Mariana Pulver  Property Price  120281.17
# 419999     C-43482   Mechelle Boddie  Property Price  133425.43
#
# [420000 rows x 4 columns]

# %% [markdown]
# ## 3.Stacking/Unstacking:
# You can stack the Property ID, Property Age, Property Type, and Property Location columns into a single column.

# %%
df.set_index(['Customer ID', 'Property ID'])[['Property Age', 'Property Type', 'Property Location']].stack().reset_index()
# Out:
#       Customer ID  Property ID            level_2           0
# 0         C-26247          843       Property Age     3472.69
# 1         C-26247          843      Property Type           2
# 2         C-26247          843  Property Location       Urban
# 3         C-35067           22       Property Age     1184.84
# 4         C-35067           22      Property Type           1
# ...           ...          ...                ...         ...
# 58943      C-3099          489      Property Type           1
# 58944      C-3099          489  Property Location  Semi-Urban
# 58945     C-43482          368       Property Age     5233.16
# 58946     C-43482          368      Property Type           4
# 58947     C-43482          368  Property Location  Semi-Urban
#
# [58948 rows x 4 columns]

# %% [markdown]
# ## 4.Reshaping with pivot_table:
# Suppose you want to pivot the data to show the average Loan Amount Request (USD) for each combination of Location and Type of Employment, while handling potential duplicates.

# %%
df.pivot_table(index='Location', columns='Type of Employment', values='Loan Amount Request (USD)', aggfunc='mean')
# Out:
# Type of Employment    Accountants  Cleaning staff  Cooking staff  \
# Location
# Rural               101322.395946    66958.592821   77525.614143
# Semi-Urban          100492.486612    74024.291437   72767.642951
# Urban               120890.238583    89519.294118  107805.449333
#
# Type of Employment     Core staff        Drivers      HR staff  \
# Location
# Rural                86313.405264   83208.721282  76465.887143
# Semi-Urban           89230.382568   85049.975779  83222.580000
# Urban               117686.591520  109190.304919  93733.648889
#
# Type of Employment  High skill tech staff      IT staff       Laborers  \
# Location
# Rural                        80266.935969  59721.061111   77981.900299
# Semi-Urban                   95319.498142  77175.404000   79803.296269
# Urban                       116965.632393  73258.701429  101219.126199
#
# Type of Employment  Low-skill Laborers       Managers  Medicine staff  \
# Location
# ...

# %% [markdown]
# # Transforming:

# %% [markdown]
# ## 1.Grouping and Aggregation:
# You can group the data by Location and Type of Employment, and compute the mean Credit Score.

# %%
df.groupby(['Location', 'Type of Employment'])['Credit Score'].mean().reset_index()
# Out:
#       Location     Type of Employment  Credit Score
# 0        Rural            Accountants    758.282536
# 1        Rural         Cleaning staff    716.177222
# 2        Rural          Cooking staff    721.015303
# 3        Rural             Core staff    731.564555
# 4        Rural                Drivers    687.243154
# 5        Rural               HR staff    768.654286
# 6        Rural  High skill tech staff    738.030165
# 7        Rural               IT staff    744.572222
# 8        Rural               Laborers    699.591211
# 9        Rural     Low-skill Laborers    655.516667
# 10       Rural               Managers    746.328945
# 11       Rural         Medicine staff    731.885524
# 12       Rural  Private service staff    737.746316
# 13       Rural          Realty agents    732.098824
# 14       Rural            Sales staff    710.351950
# 15       Rural            Secretaries    729.781176
# 16       Rural         Security staff    710.872949
# ...

# %% [markdown]
# ## 2.Applying Functions:
# Suppose you want to create a new column Loan Amount Category based on the Loan Amount Request (USD) values.

# %%
df['Loan Amount Category'] = df['Loan Amount Request (USD)'].apply(lambda x: 'High' if x > 100000 else 'Low')
df['Loan Amount Category']
# Out:
# 0        High
# 1        High
# 2        High
# 3         Low
# 4        High
#          ...
# 19995    High
# 19996     Low
# 19997     Low
# 19998     Low
# 19999    High
# Name: Loan Amount Category, Length: 20000, dtype: object

# %% [markdown]
# ## 3.Dropping Duplicates:
# If you want to remove duplicate rows based on Customer ID and Property ID, you can use drop_duplicates().

# %%
deduped_df = df.drop_duplicates(subset=['Customer ID', 'Property ID'])
deduped_df
# Out:
#       Customer ID              Name Gender  Age  Income (USD)  \
# 0         C-26247  Tandra Olszewski      F   47       3472.69
# 1         C-35067     Jeannette Cha      F   57       1184.84
# 2         C-34590      Keva Godfrey      F   52       1266.27
# 3         C-16668      Elva Sackett      M   65       1369.72
# 4         C-12196    Sade Constable      F   60       1939.23
# ...           ...               ...    ...  ...           ...
# 19995      C-9076    Tobias Davilla      F   19       1349.60
# 19996     C-17587    Evelina Hodges      M   22       2019.78
# 19997     C-46479   Karlyn Mckinzie      M   19       2252.03
# 19998      C-3099    Mariana Pulver      F   21       1845.35
# 19999     C-43482   Mechelle Boddie      M   21       5233.16
#
#       Income Stability            Profession Type of Employment    Location  \
# 0                  Low  Commercial associate           Managers  Semi-Urban
# ...

# %% [markdown]
# ## 4.Renaming Columns:
# You can rename columns to make them more readable or consistent.

# %%
renamed_df = df.rename(columns={'Income (USD)': 'Income', 'Loan Amount Request (USD)': 'Loan Amount'})
renamed_df.columns
# Out:
# Index(['Customer ID', 'Name', 'Gender', 'Age', 'Income', 'Income Stability',
#        'Profession', 'Type of Employment', 'Location', 'Loan Amount',
#        'Current Loan Expenses (USD)', 'Expense Type 1', 'Expense Type 2',
#        'Dependents', 'Credit Score', 'No. of Defaults',
#        'Has Active Credit Card', 'Property ID', 'Property Age',
#        'Property Type', 'Property Location', 'Co-Applicant', 'Property Price',
#        'Loan Amount Category'],
#       dtype='object')
